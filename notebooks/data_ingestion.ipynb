# %%
import duckdb
import pandas as ps

with open ('../sql/load_sakila.sql', 'r') as sql_file:
    loading_script = sql_file.read()

# %%
print(loading_script)
# Out:
# INSTALL sqlite;
#
# LOAD sqlite;
#
# CALL sqlite_attach ('../data/sqlite-sakila.db');

# %%
from pathlib import Path

duckdb_path = '../data/sakila.duckdb'

Path(duckdb_path).unlink(missing_ok=True)

with duckdb.connect(duckdb_path) as conn:
    conn.sql(loading_script)

    description = conn.sql('desc;').df()
    films = conn.sql('FROM film;').df()
    

description
# Out:
#    database schema                    name  \
# 0    sakila   main                   actor
# 1    sakila   main                 address
# 2    sakila   main                category
# 3    sakila   main                    city
# 4    sakila   main                 country
# 5    sakila   main                customer
# 6    sakila   main           customer_list
# 7    sakila   main                    film
# 8    sakila   main              film_actor
# 9    sakila   main           film_category
# 10   sakila   main               film_list
# 11   sakila   main               film_text
# 12   sakila   main               inventory
# 13   sakila   main                language
# 14   sakila   main                 payment
# 15   sakila   main                  rental
# 16   sakila   main  sales_by_film_category
# 17   sakila   main          sales_by_store
# 18   sakila   main                   staff
# 19   sakila   main              staff_list
# 20   sakila   main                   store
#
#                                          column_names  \
# 0      [actor_id, first_name, last_name, last_update]
# 1   [address_id, address, address2, district, city...
# 2                    [category_id, name, last_update]
# 3            [city_id, city, country_id, last_update]
# 4                  [country_id, country, last_update]
# 5   [customer_id, store_id, first_name, last_name,...
# 6   [ID, name, address, zip_code, phone, city, cou...
# 7   [film_id, title, description, release_year, la...
# 8                    [actor_id, film_id, last_update]
# 9                 [film_id, category_id, last_update]
# 10  [FID, title, description, category, price, len...
# 11                      [film_id, title, description]
# 12     [inventory_id, film_id, store_id, last_update]
# 13                   [language_id, name, last_update]
# 14  [payment_id, customer_id, staff_id, rental_id,...
# 15  [rental_id, rental_date, inventory_id, custome...
# 16                            [category, total_sales]
# 17            [store_id, store, manager, total_sales]
# 18  [staff_id, first_name, last_name, address_id, ...
# 19  [ID, name, address, zip_code, phone, city, cou...
# 20  [store_id, manager_staff_id, address_id, last_...
#
#                                          column_types  temporary
# 0               [DOUBLE, VARCHAR, VARCHAR, TIMESTAMP]      False
# 1   [BIGINT, VARCHAR, VARCHAR, VARCHAR, BIGINT, VA...      False
# 2                        [BIGINT, VARCHAR, TIMESTAMP]      False
# 3                [BIGINT, VARCHAR, BIGINT, TIMESTAMP]      False
# 4                        [BIGINT, VARCHAR, TIMESTAMP]      False
# 5   [BIGINT, BIGINT, VARCHAR, VARCHAR, VARCHAR, BI...      False
# 6   [BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR, V...      False
# 7   [BIGINT, VARCHAR, VARCHAR, VARCHAR, BIGINT, BI...      False
# 8                         [BIGINT, BIGINT, TIMESTAMP]      False
# 9                         [BIGINT, BIGINT, TIMESTAMP]      False
# 10  [BIGINT, VARCHAR, VARCHAR, VARCHAR, DOUBLE, BI...      False
# 11                         [BIGINT, VARCHAR, VARCHAR]      False
# 12                [BIGINT, BIGINT, BIGINT, TIMESTAMP]      False
# 13                       [BIGINT, VARCHAR, TIMESTAMP]      False
# 14  [BIGINT, BIGINT, BIGINT, BIGINT, DOUBLE, TIMES...      False
# 15  [BIGINT, TIMESTAMP, BIGINT, BIGINT, TIMESTAMP,...      False
# 16                                  [VARCHAR, DOUBLE]      False
# 17                 [BIGINT, VARCHAR, VARCHAR, DOUBLE]      False
# 18  [BIGINT, VARCHAR, VARCHAR, BIGINT, BLOB, VARCH...      False
# 19  [BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR, V...      False
# 20                [BIGINT, BIGINT, BIGINT, TIMESTAMP]      False

# %%
films
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...         2006
# 1    A Astounding Epistle of a Database Administrat...         2006
# 2    A Astounding Reflection of a Lumberjack And a ...         2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...         2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...         2006
# ..                                                 ...          ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...         2006
# 996  A Touching Drama of a Teacher And a Cat who mu...         2006
# 997  A Fateful Yarn of a Composer And a Man who mus...         2006
# 998  A Fateful Reflection of a Waitress And a Boat ...         2006
# 999  A Intrepid Panorama of a Mad Scientist And a B...         2006
#
#      language_id  original_language_id  rental_duration  rental_rate  length  \
# 0              1                  <NA>                6         0.99      86
# 1              1                  <NA>                3         4.99      48
# 2              1                  <NA>                7         2.99      50
# 3              1                  <NA>                5         2.99     117
# 4              1                  <NA>                6         2.99     130
# ..           ...                   ...              ...          ...     ...
# 995            1                  <NA>                6         0.99     183
# 996            1                  <NA>                4         0.99     179
# 997            1                  <NA>                6         0.99     105
# 998            1                  <NA>                5         2.99     101
# 999            1                  <NA>                3         4.99      50
#
#      replacement_cost rating                         special_features  \
# 0               20.99     PG         Deleted Scenes,Behind the Scenes
# 1               12.99      G                  Trailers,Deleted Scenes
# 2               18.99  NC-17                  Trailers,Deleted Scenes
# 3               26.99      G           Commentaries,Behind the Scenes
# 4               22.99      G                           Deleted Scenes
# ..                ...    ...                                      ...
# 995              9.99      G               Trailers,Behind the Scenes
# 996             14.99  NC-17               Trailers,Behind the Scenes
# 997             10.99  NC-17                           Deleted Scenes
# 998             28.99      R                  Trailers,Deleted Scenes
# 999             18.99  NC-17  Trailers,Commentaries,Behind the Scenes
#
#             last_update
# 0   2021-03-06 15:52:00
# 1   2021-03-06 15:52:00
# 2   2021-03-06 15:52:00
# 3   2021-03-06 15:52:00
# 4   2021-03-06 15:52:00
# ..                  ...
# 995 2021-03-06 15:52:08
# 996 2021-03-06 15:52:08
# 997 2021-03-06 15:52:08
# 998 2021-03-06 15:52:08
# 999 2021-03-06 15:52:08
#
# [1000 rows x 13 columns]

# %%
films['length']
films[films['length'] > 180]
# Out:
#      film_id               title  \
# 23        24    ANALYZE HOOSIERS
# 49        50     BAKED CLEOPATRA
# 127      128       CATCH AMISTAD
# 140      141       CHICAGO NORTH
# 179      180   CONSPIRACY SPIRIT
# 181      182      CONTROL ANTHEM
# 197      198    CRYSTAL BREAKING
# 211      212      DARN FORRESTER
# 339      340      FRONTIER CABIN
# 348      349         GANGS PRIDE
# 405      406    HAUNTING PIANIST
# 425      426           HOME PITY
# 434      435     HOTEL HAPPINESS
# 466      467      INTRIGUE WORST
# 472      473       JACKET FRISCO
# 498      499      KING EVOLUTION
# 509      510      LAWLESS VISION
# 534      535       LOVE SUICIDES
# 590      591       MONSOON CAUSE
# 596      597     MOONWALKER FOOL
# 608      609       MUSCLE BRIGHT
# 689      690        POND SEATTLE
# 718      719       RECORDS ZORRO
# 720      721          REDS POCUS
# 750      751  RUNAWAY TENENBAUMS
# 764      765         SATURN NAME
# 766      767       SCALAWAG DUCK
# 773      774      SEARCHERS WAIT
# 812      813     SMOOCHY CONTROL
# 816      817  SOLDIERS EVOLUTION
# 819      820      SONS INTERVIEW
# 820      821      SORORITY QUEEN
# 840      841      STAR OPERATION
# 871      872   SWEET BROTHERHOOD
# 885      886      THEORY MERMAID
# 972      973           WIFE TURN
# 973      974         WILD APOLLO
# 990      991        WORST BANGER
# 995      996      YOUNG LANGUAGE
#
#                                            description release_year  \
# 23   A Thoughtful Display of a Explorer And a Pastr...         2006
# 49   A Stunning Drama of a Forensic Psychologist An...         2006
# 127  A Boring Reflection of a Lumberjack And a Femi...         2006
# 140  A Fateful Yarn of a Mad Cow And a Waitress who...         2006
# 179  A Awe-Inspiring Story of a Student And a Frisb...         2006
# 181  A Fateful Documentary of a Robot And a Student...         2006
# 197  A Fast-Paced Character Study of a Feminist And...         2006
# 211  A Fateful Story of a A Shark And a Explorer wh...         2006
# 339  A Emotional Story of a Madman And a Waitress w...         2006
# 348  A Taut Character Study of a Woman And a A Shar...         2006
# 405  A Fast-Paced Story of a Database Administrator...         2006
# 425  A Touching Panorama of a Man And a Secret Agen...         2006
# 434  A Thrilling Yarn of a Pastry Chef And a A Shar...         2006
# 466  A Fanciful Character Study of a Explorer And a...         2006
# 472  A Insightful Reflection of a Womanizer And a H...         2006
# 498  A Action-Packed Tale of a Boy And a Lumberjack...         2006
# 509  A Insightful Yarn of a Boy And a Sumo Wrestler...         2006
# 534  A Brilliant Panorama of a Hunter And a Explore...         2006
# 590  A Astounding Tale of a Crocodile And a Car who...         2006
# 596  A Epic Drama of a Feminist And a Pioneer who m...         2006
# 608  A Stunning Panorama of a Sumo Wrestler And a H...         2006
# 689  A Stunning Drama of a Teacher And a Boat who m...         2006
# 718  A Amazing Drama of a Mad Scientist And a Compo...         2006
# 720  A Lacklusture Yarn of a Sumo Wrestler And a Sq...         2006
